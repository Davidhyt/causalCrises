# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Set the seaborn style to 'darkgrid'
sns.set_style('darkgrid')

# Execute the matplotlib magic function to ensure plots are displayed inline
# %matplotlib inline

# %%
country_synonym = {'Armenia, Rep. of': 'Armenia',
 'Belarus, Rep. of': 'Belarus',
 'Azerbaijan, Rep. of': 'Azerbaijan',
 'Brunei Darussalam': 'Brunei',
 'Central African Republic': 'Central African Rep.',
 'China, P.R.: Mainland': 'China, P.R.',
 'Comoros, Union of the': 'Comoros',
 'Democratic Republic of the Congo': 'Congo, Dem. Rep. of',
 'Republic of Congo': 'Congo, Rep. of',
 "CÙte d'Ivoire": 'Côte d’Ivoire',
 'Croatia, Rep. of': 'Croatia',
 'Czech Rep.': 'Czech Republic',
 'Dominican Rep.': 'Dominican Republic',
 'Egypt, Arab Rep. of': 'Egypt',
 'Equatorial Guinea, Rep. of': 'Equatorial Guinea',
 'Estonia, Rep. of': 'Estonia',
 'Ethiopia, The Federal Dem. Rep. of': 'Ethiopia',
 'The Gambia': 'Gambia, The',
 'Hong Kong SAR': 'China, P.R.: Hong Kong',
 'Iran, Islamic Rep. of': 'Iran, I.R. of',
 'Kazakhstan, Rep. of': 'Kazakhstan',
 'Korea, Rep. of': 'Korea',
 'Kyrgyz Rep.': 'Kyrgyz Republic',
 'Lesotho, Kingdom of': 'Lesotho',
 'Lao P.D.R.': 'Lao People’s Dem. Rep.',
 'Madagascar, Rep. of': 'Madagascar',
 'Mauritania, Islamic Rep. of': 'Mauritania',
 'Moldova, Rep. of': 'Moldova',
 'Mozambique, Rep. of': 'Mozambique',
 'Netherlands, The': 'Netherlands',
 'Poland, Rep. of': 'Poland',
 'Russian Federation': 'Russia',
 'São Tomé and Príncipe, Dem. Rep. of': 'São Tomé and Principe',
 'Slovak Rep.': 'Slovak Republic',
 'Slovenia, Rep. of': 'Slovenia',
 'South Sudan, Rep. of': 'South Sudan',
 'Tajikistan, Rep. of': 'Tajikistan',
 'Tanzania, United Rep. of': 'Tanzania',
 'Türkiye, Rep of': 'Turkey',
 'Uzbekistan, Rep. of': 'Uzbekistan',
 'Venezuela, Rep. Bolivariana de': 'Venezuela',
 'Yemen, Rep. of': 'Yemen',
 'Yemen, Republic of': 'Yemen',
 'Serbia, Rep. of': 'Serbia, Republic of',
 'Syria': 'Syrian Arab Republic',
 'North Macedonia': 'Macedonia', 
 'Congo, Republic of': 'Congo, Rep. of'}

# %%
commodity = pd.read_csv('../project/IMF_data/commodity.csv')
CPI = pd.read_csv('../project/IMF_data/CPI.csv')
fiscal_balance = pd.read_csv('../project/IMF_data/Fiscal_Balance.csv')
fx_reserve = pd.read_csv('../project/IMF_data/Foreign_Exchange_Reserve.csv')
interest_rate = pd.read_csv('../project/IMF_data/interest_rate.csv')
revenue = pd.read_csv('../project/IMF_data/revenue.csv')
financial_dev = pd.read_csv('../project/IMF_data/financial_development.csv')
confounding_all = pd.read_excel('../project/IMF_data/all.xlsx')
df_list = [commodity, CPI, fiscal_balance, fx_reserve, interest_rate, confounding_all]
for df in df_list:
    if 'Country Name' in df.columns:
        for i in range(len(df)):
            c = df['Country Name'].iloc[i]
            if c in country_synonym.keys():
                df['Country Name'].iloc[i] = country_synonym[c]
    elif 'Country' in df.columns:
        for i in range(len(df.Country)):
            c = df.Country[i]
            if c in country_synonym.keys():
                df.Country[i] = country_synonym[c]
    else:
        print('failed to check country names')
commodity.set_index('Country Name', inplace=True)
commodity.drop(columns='Unnamed: 67', inplace=True)
CPI.set_index('Country Name', inplace=True)
CPI.drop(columns='Unnamed: 78', inplace=True)
fiscal_balance.set_index('Country Name', inplace=True)
fiscal_balance.drop(columns='Unnamed: 42', inplace=True)
fx_reserve.set_index('Country Name', inplace=True)
fx_reserve.drop(columns='Unnamed: 33', inplace=True)
interest_rate.set_index('Country Name', inplace=True)
interest_rate.drop(columns='Unnamed: 79', inplace=True)
revenue.set_index('Country Name', inplace=True)
revenue.drop(columns='Unnamed: 37', inplace=True)
financial_dev.set_index('Country Name', inplace=True)
financial_dev.drop(columns='Unnamed: 46', inplace=True)
confounding_all.set_index('Country', inplace=True)

countries_and_dates = pd.read_excel('../project/IMF_data/input_country_dates.xlsx', index_col='Country')

# %%
outcome = pd.read_excel('../project/IMF_data/y2.xlsx')
final_countries = outcome['Countries'].drop_duplicates().values
outcome = outcome.set_index(['Countries', 'Year'])
outcome
# Out:
#                         Y
# Countries Year
# Albania   1996   0.151003
#           1997   0.338851
#           1998   0.302328
#           1999   0.270191
#           2000   0.218068
# ...                   ...
# Zimbabwe  2015   0.104093
#           2016   0.144387
#           2017   6.242911
#           2018  46.825736
#           2019  46.825736
#
# [3556 rows x 1 columns]

# %%
display(countries_and_dates)
display(confounding_all)
# Out:
#                                 Banking                      Currency  \
# Country
# Albania                            1994                          1997
# Algeria                            1990                    1988, 1994
# Angola                              NaN              1991, 1996, 2015
# Argentina        1980, 1989, 1995, 2001  1975, 1981, 1987, 2002, 2013
# Armenia                            1994                           NaN
# ...                                 ...                           ...
# Vietnam                            1997              1972, 1981, 1987
# Yemen                              1996                    1985, 1995
# Yugoslavia, SFR                     NaN                           NaN
# Zambia                             1995  1983, 1989, 1996, 2009, 2015
# Zimbabwe                           1995        1983, 1991, 1998, 2003
#
#                         Sovereign Sovereign_restructuring
# Country
# Albania                      1990                    1992
# Algeria                       NaN                     NaN
# Angola                       1988                    1992
# Argentina        1982, 2001, 2014        1993, 2005, 2016
# Armenia                       NaN                     NaN
# ...                           ...                     ...
# Vietnam                      1985                    1997
# Yemen                         NaN                     NaN
# Yugoslavia, SFR              1983                    1988
# Zambia                       1983                    1994
# Zimbabwe                      NaN                     NaN
#
# [165 rows x 4 columns]
#              WEO Country Code  ISO WEO Subject Code  \
# Country
# Afghanistan               512  AFG           NGDP_R
# Afghanistan               512  AFG        NGDP_RPCH
# Afghanistan               512  AFG             NGDP
# Afghanistan               512  AFG            NGDPD
# Afghanistan               512  AFG           PPPGDP
# ...                       ...  ...              ...
# Zimbabwe                  698  ZWE           GGXWDG
# Zimbabwe                  698  ZWE      GGXWDG_NGDP
# Zimbabwe                  698  ZWE          NGDP_FY
# Zimbabwe                  698  ZWE              BCA
# Zimbabwe                  698  ZWE        BCA_NGDPD
#
#                                             Subject Descriptor  \
# Country
# Afghanistan            Gross domestic product, constant prices
# Afghanistan            Gross domestic product, constant prices
# Afghanistan             Gross domestic product, current prices
# Afghanistan             Gross domestic product, current prices
# Afghanistan             Gross domestic product, current prices
# ...                                                        ...
# Zimbabwe                         General government gross debt
# Zimbabwe                         General government gross debt
# Zimbabwe     Gross domestic product corresponding to fiscal...
# Zimbabwe                               Current account balance
# Zimbabwe                               Current account balance
#
#                                                  Subject Notes  \
# Country
# Afghanistan  Expressed in billions of national currency uni...
# Afghanistan  Annual percentages of constant price GDP are y...
# Afghanistan  Expressed in billions of national currency uni...
# Afghanistan  Values are based upon GDP in national currency...
# Afghanistan  These data form the basis for the country weig...
# ...                                                        ...
# Zimbabwe     Gross debt consists of all liabilities that re...
# Zimbabwe     Gross debt consists of all liabilities that re...
# Zimbabwe     Gross domestic product corresponding to fiscal...
# Zimbabwe     Current account is all transactions other than...
# Zimbabwe     Current account is all transactions other than...
#
#                                                       Units     Scale  \
# Country
# Afghanistan                               National currency  Billions
# Afghanistan                                  Percent change       NaN
# Afghanistan                               National currency  Billions
# Afghanistan                                    U.S. dollars  Billions
# Afghanistan  Purchasing power parity; international dollars  Billions
# ...                                                     ...       ...
# Zimbabwe                                  National currency  Billions
# Zimbabwe                                     Percent of GDP       NaN
# Zimbabwe                                  National currency  Billions
# Zimbabwe                                       U.S. dollars  Billions
# Zimbabwe                                     Percent of GDP       NaN
#
#                                  Country/Series-specific Notes   1980   1981  \
# Country
# Afghanistan  Source: National Statistics Office Latest actu...    NaN    NaN
# Afghanistan  See notes for:  Gross domestic product, consta...    NaN    NaN
# Afghanistan  Source: National Statistics Office Latest actu...    NaN    NaN
# Afghanistan  See notes for:  Gross domestic product, curren...    NaN    NaN
# Afghanistan  See notes for:  Gross domestic product, curren...    NaN    NaN
# ...                                                        ...    ...    ...
# Zimbabwe     Source: Ministry of Finance or Treasury Latest...    NaN    NaN
# Zimbabwe     See notes for:  General government gross debt ...    NaN    NaN
# Zimbabwe     Source: Ministry of Finance or Treasury Latest...    NaN    NaN
# Zimbabwe     Source: Reserve Bank of Zimbabwe and Ministry ... -0.301 -0.674
# Zimbabwe     See notes for:  Gross domestic product, curren...    NaN    NaN
#
#              ...     2019     2020     2021      2022      2023      2024  \
# Country      ...
# Afghanistan  ...   1319.9  1288.87      NaN       NaN       NaN       NaN
# Afghanistan  ...    3.912   -2.351      NaN       NaN       NaN       NaN
# Afghanistan  ...   1469.6  1547.29      NaN       NaN       NaN       NaN
# Afghanistan  ...   18.876   20.136      NaN       NaN       NaN       NaN
# Afghanistan  ...   81.873   80.912      NaN       NaN       NaN       NaN
# ...          ...      ...      ...      ...       ...       ...       ...
# Zimbabwe     ...  174.699  1218.76  1947.91  13347.46  27224.17  41501.09
# Zimbabwe     ...   93.213  102.491   66.913    92.635    64.872    57.489
# Zimbabwe     ...  187.419  1189.14  2911.11  14408.63   41965.7  72190.13
# Zimbabwe     ...     0.92    0.678    0.348     0.215     0.096     0.149
# Zimbabwe     ...    4.003    2.926    1.059     0.561     0.257     0.384
#
#                  2025       2026       2027 Estimates Start After
# Country
# Afghanistan       NaN        NaN        NaN                2020.0
# Afghanistan       NaN        NaN        NaN                2020.0
# Afghanistan       NaN        NaN        NaN                2020.0
# Afghanistan       NaN        NaN        NaN                2020.0
# Afghanistan       NaN        NaN        NaN                2020.0
# ...               ...        ...        ...                   ...
# Zimbabwe     52964.56   60566.34   67806.72                2019.0
# Zimbabwe       54.497      53.13     51.395                2019.0
# Zimbabwe     97188.08  113996.38  131931.52                2019.0
# Zimbabwe        0.206      0.237      0.201                2020.0
# Zimbabwe        0.531      0.612      0.498                2019.0
#
# [8624 rows x 57 columns]

# %%
country_name = countries_and_dates.index.to_list()

# %%
cn = []
for n in country_name:
    cn += [n]*(2023-1950)
y = []
for n in country_name:
    y += np.arange(1950, 2023).astype(str).tolist()    

input_df = pd.DataFrame(columns=['Treatment:Banking', 'Treatment:Currency', 'Treatment:Sovereign','Treatment:Sovereign_restructuring',
                'Gross domestic product, constant prices', 'Output gap in percent of potential GDP', 'Implied PPP conversion rate',
                'Total investment', 'Gross national savings', 'Inflation, average consumer prices', 
                'Volume of imports of goods and services', 'Volume of exports of goods and services', 
                'Unemployment rate', 'General government gross debt', 'Current account balance',
                'Commodity Export Price Index, Individual Commodites Weighted by Ratio of Exports to GDP',
                'Commodity Import Price Index, Individual Commodites Weighted by Ratio of Imports to GDP',
                'Commodity Net Export Price Index, Individual Commodities Weighted by Ratio of Net Exports to GDP',
                'Consumer Price Index, All items', 'Financial, Interest Rates, Money Market, Percent per annum',
                'Cyclically adjusted balance (% of potential GDP)',
                'Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars',
                'Corporate Income Tax Revenue in Percent of GDP', 'Goods and Services Tax Revenue in Percent of GDP',
                'Financial Development Index', 'Financial Institutions Index', 'Financial Markets Index',
                'Outcome'], 
                index = [cn, y])
input_df
# Out:
#               Treatment:Banking Treatment:Currency Treatment:Sovereign  \
# Albania  1950               NaN                NaN                 NaN
#          1951               NaN                NaN                 NaN
#          1952               NaN                NaN                 NaN
#          1953               NaN                NaN                 NaN
#          1954               NaN                NaN                 NaN
# ...                         ...                ...                 ...
# Zimbabwe 2018               NaN                NaN                 NaN
#          2019               NaN                NaN                 NaN
#          2020               NaN                NaN                 NaN
#          2021               NaN                NaN                 NaN
#          2022               NaN                NaN                 NaN
#
#               Treatment:Sovereign_restructuring  \
# Albania  1950                               NaN
#          1951                               NaN
#          1952                               NaN
#          1953                               NaN
#          1954                               NaN
# ...                                         ...
# Zimbabwe 2018                               NaN
#          2019                               NaN
#          2020                               NaN
#          2021                               NaN
#          2022                               NaN
#
#               Gross domestic product, constant prices  \
# Albania  1950                                     NaN
#          1951                                     NaN
#          1952                                     NaN
#          1953                                     NaN
#          1954                                     NaN
# ...                                               ...
# Zimbabwe 2018                                     NaN
#          2019                                     NaN
#          2020                                     NaN
#          2021                                     NaN
#          2022                                     NaN
#
#               Output gap in percent of potential GDP  \
# Albania  1950                                    NaN
#          1951                                    NaN
#          1952                                    NaN
#          1953                                    NaN
#          1954                                    NaN
# ...                                              ...
# Zimbabwe 2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#          2021                                    NaN
#          2022                                    NaN
#
#               Implied PPP conversion rate Total investment  \
# Albania  1950                         NaN              NaN
#          1951                         NaN              NaN
#          1952                         NaN              NaN
#          1953                         NaN              NaN
#          1954                         NaN              NaN
# ...                                   ...              ...
# Zimbabwe 2018                         NaN              NaN
#          2019                         NaN              NaN
#          2020                         NaN              NaN
#          2021                         NaN              NaN
#          2022                         NaN              NaN
#
#               Gross national savings Inflation, average consumer prices  ...  \
# Albania  1950                    NaN                                NaN  ...
#          1951                    NaN                                NaN  ...
#          1952                    NaN                                NaN  ...
#          1953                    NaN                                NaN  ...
#          1954                    NaN                                NaN  ...
# ...                              ...                                ...  ...
# Zimbabwe 2018                    NaN                                NaN  ...
#          2019                    NaN                                NaN  ...
#          2020                    NaN                                NaN  ...
#          2021                    NaN                                NaN  ...
#          2022                    NaN                                NaN  ...
#
#               Consumer Price Index, All items  \
# Albania  1950                             NaN
#          1951                             NaN
#          1952                             NaN
#          1953                             NaN
#          1954                             NaN
# ...                                       ...
# Zimbabwe 2018                             NaN
#          2019                             NaN
#          2020                             NaN
#          2021                             NaN
#          2022                             NaN
#
#               Financial, Interest Rates, Money Market, Percent per annum  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Cyclically adjusted balance (% of potential GDP)  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Corporate Income Tax Revenue in Percent of GDP  \
# Albania  1950                                            NaN
#          1951                                            NaN
#          1952                                            NaN
#          1953                                            NaN
#          1954                                            NaN
# ...                                                      ...
# Zimbabwe 2018                                            NaN
#          2019                                            NaN
#          2020                                            NaN
#          2021                                            NaN
#          2022                                            NaN
#
#               Goods and Services Tax Revenue in Percent of GDP  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Financial Development Index Financial Institutions Index  \
# Albania  1950                         NaN                          NaN
#          1951                         NaN                          NaN
#          1952                         NaN                          NaN
#          1953                         NaN                          NaN
#          1954                         NaN                          NaN
# ...                                   ...                          ...
# Zimbabwe 2018                         NaN                          NaN
#          2019                         NaN                          NaN
#          2020                         NaN                          NaN
#          2021                         NaN                          NaN
#          2022                         NaN                          NaN
#
#               Financial Markets Index Outcome
# Albania  1950                     NaN     NaN
#          1951                     NaN     NaN
#          1952                     NaN     NaN
#          1953                     NaN     NaN
#          1954                     NaN     NaN
# ...                               ...     ...
# Zimbabwe 2018                     NaN     NaN
#          2019                     NaN     NaN
#          2020                     NaN     NaN
#          2021                     NaN     NaN
#          2022                     NaN     NaN
#
# [12045 rows x 28 columns]

# %%
for c in country_name:
    for treatment in ['Banking', 'Currency', 'Sovereign', 'Sovereign_restructuring']:
        year = countries_and_dates.loc[c, treatment]
        if pd.notna(year):
            if type(year) == int:
                input_df['Treatment:'+treatment].loc[c, str(year)] = 1
            elif type(year) == str:
                year = year.split(', ')
                input_df['Treatment:'+treatment].loc[c, year] = 1
    
input_df[['Treatment:Banking','Treatment:Currency', 'Treatment:Sovereign', 'Treatment:Sovereign_restructuring']] = input_df[['Treatment:Banking','Treatment:Currency', 'Treatment:Sovereign', 'Treatment:Sovereign_restructuring']].fillna(0)

# %%
input_df.sort_index(ascending=True, inplace=True)

# %%
confunding_var = {'Gross domestic product, constant prices':'Percent change', 
                  'Output gap in percent of potential GDP':'Percent of potential GDP',
                  'Implied PPP conversion rate':'National currency per current international dollar',
                  'Total investment':'Percent of GDP', 'Gross national savings':'Percent of GDP',
                  'Inflation, average consumer prices':'Percent change',
                  'Volume of imports of goods and services':'Percent change',
                  'Volume of exports of goods and services':'Percent change', 
                  'Unemployment rate':'Percent of total labor force',
                  'General government gross debt':'Percent of GDP',
                  'Current account balance':'Percent of GDP'}

# %%
for c in country_name:
    if c in confounding_all.index:
        for var in confunding_var.keys():
            cv_val = confounding_all[(confounding_all['Subject Descriptor']==var)&(confounding_all.Units==confunding_var[var])][np.arange(1980, 2023).tolist()].loc[c]
            input_df[var].loc[c,'1980':'2022']=cv_val.values

# %%
commodity_var = ['Commodity Export Price Index, Individual Commodites Weighted by Ratio of Exports to GDP',
                'Commodity Import Price Index, Individual Commodites Weighted by Ratio of Imports to GDP',
                'Commodity Net Export Price Index, Individual Commodities Weighted by Ratio of Net Exports to GDP']

for c in final_countries:
    if c in commodity.index:
        for var in commodity_var:
            cv_val = commodity[(commodity['Indicator Name'] == var)&(commodity['Type Name']=='Historical, Fixed Weights, Index')][np.arange(1962, 2022).astype(str).tolist()].loc[c]
            input_df[var].loc[c,'1962':'2021']=cv_val.values

# %%
for c in final_countries:
    if c in CPI.index:
        cpi_val = CPI[CPI.Attribute=='Value'][np.arange(1950, 2022).astype(str).tolist()].loc[c]
        input_df['Consumer Price Index, All items'].loc[c,'1950':'2021']=cpi_val.values

# %%
for c in final_countries:
    if c in interest_rate.index:
        interest_rate_val = interest_rate[(interest_rate['Indicator Name']=='Financial, Interest Rates, Money Market, Percent per annum')&(interest_rate.Attribute=='Value')][np.arange(1950, 2023).astype(str).tolist()].loc[c]
        input_df['Financial, Interest Rates, Money Market, Percent per annum'].loc[c,'1950':'2022']=interest_rate_val.values

# %%
fiscal_balance_valid = fiscal_balance[fiscal_balance['Indicator Name']=='Cyclically adjusted balance (% of potential GDP)']
for c in final_countries:
    if c in fiscal_balance_valid.index:
        fiscal_balance_val = fiscal_balance_valid[np.arange(1991, 2023).astype(str).tolist()].loc[c]
        input_df['Cyclically adjusted balance (% of potential GDP)'].loc[c,'1991':'2022']=fiscal_balance_val.values

# %%
for c in final_countries:
    if c in fx_reserve.index:
        fx_reserve_val = fx_reserve[(fx_reserve['Indicator Name']=='Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars')&(fx_reserve.Attribute=='Value')][np.arange(1996, 2022).astype(str).tolist()].loc[c]
        if len(fx_reserve_val.shape) > 1:
            fx_reserve_val = fx_reserve_val.iloc[0]
        input_df['Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars'].loc[c,'1996':'2021']=fx_reserve_val.values

# %%
revenue_var = ['Corporate Income Tax Revenue in Percent of GDP', 'Goods and Services Tax Revenue in Percent of GDP']
revenue_valid1 = revenue[(revenue['Indicator Name'] == revenue_var[0])&(revenue.Attribute=='Value')]
revenue_valid2 = revenue[(revenue['Indicator Name'] == revenue_var[1])&(revenue.Attribute=='Value')]
for c in final_countries:
    if c in revenue_valid1.index and c in revenue_valid2.index:
        for var in revenue_var:
            rv_val = revenue[(revenue['Indicator Name'] == var)&(revenue.Attribute=='Value')][np.arange(1990, 2022).astype(str).tolist()].loc[c]
            input_df[var].loc[c,'1990':'2021']=rv_val.values

# %%
fin_dev_var = ['Financial Development Index', 'Financial Institutions Index', 'Financial Markets Index']
for c in final_countries:
    if c in financial_dev.index:
        for var in fin_dev_var:
            fd_val = financial_dev[(financial_dev['Indicator Name'] == var)&(financial_dev.Attribute=='Value')][np.arange(1980, 2021).astype(str).tolist()].loc[c]
            input_df[var].loc[c,'1980':'2020']=fd_val.values

# %%
for c in final_countries:
    year = outcome.loc[c].index.values.astype(str).tolist()
    input_df['Outcome'].loc[c].loc[year] = outcome.loc[c]['Y'].values
input_df
# Out:
#                Treatment:Banking  Treatment:Currency  Treatment:Sovereign  \
# Albania  1950                  0                   0                    0
#          1951                  0                   0                    0
#          1952                  0                   0                    0
#          1953                  0                   0                    0
#          1954                  0                   0                    0
# ...                          ...                 ...                  ...
# Zimbabwe 2018                  0                   0                    0
#          2019                  0                   0                    0
#          2020                  0                   0                    0
#          2021                  0                   0                    0
#          2022                  0                   0                    0
#
#                Treatment:Sovereign_restructuring  \
# Albania  1950                                  0
#          1951                                  0
#          1952                                  0
#          1953                                  0
#          1954                                  0
# ...                                          ...
# Zimbabwe 2018                                  0
#          2019                                  0
#          2020                                  0
#          2021                                  0
#          2022                                  0
#
#               Gross domestic product, constant prices  \
# Albania  1950                                     NaN
#          1951                                     NaN
#          1952                                     NaN
#          1953                                     NaN
#          1954                                     NaN
# ...                                               ...
# Zimbabwe 2018                                   4.732
#          2019                                  -6.144
#          2020                                  -5.156
#          2021                                   7.159
#          2022                                   3.002
#
#               Output gap in percent of potential GDP  \
# Albania  1950                                    NaN
#          1951                                    NaN
#          1952                                    NaN
#          1953                                    NaN
#          1954                                    NaN
# ...                                              ...
# Zimbabwe 2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#          2021                                    NaN
#          2022                                    NaN
#
#               Implied PPP conversion rate Total investment  \
# Albania  1950                         NaN              NaN
#          1951                         NaN              NaN
#          1952                         NaN              NaN
#          1953                         NaN              NaN
#          1954                         NaN              NaN
# ...                                   ...              ...
# Zimbabwe 2018                       1.032              NaN
#          2019                       5.482              NaN
#          2020                      36.237              NaN
#          2021                      79.482              NaN
#          2022                     356.582              NaN
#
#               Gross national savings Inflation, average consumer prices  ...  \
# Albania  1950                    NaN                                NaN  ...
#          1951                    NaN                                NaN  ...
#          1952                    NaN                                NaN  ...
#          1953                    NaN                                NaN  ...
#          1954                    NaN                                NaN  ...
# ...                              ...                                ...  ...
# Zimbabwe 2018                    NaN                             10.607  ...
#          2019                    NaN                            255.292  ...
#          2020                    NaN                             557.21  ...
#          2021                    NaN                             98.546  ...
#          2022                    NaN                            284.938  ...
#
#               Consumer Price Index, All items  \
# Albania  1950                             NaN
#          1951                             NaN
#          1952                             NaN
#          1953                             NaN
#          1954                             NaN
# ...                                       ...
# Zimbabwe 2018                          67.625
#          2019                         240.275
#          2020                1579.09166666667
#          2021                        3135.225
#          2022                             NaN
#
#               Financial, Interest Rates, Money Market, Percent per annum  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Cyclically adjusted balance (% of potential GDP)  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Corporate Income Tax Revenue in Percent of GDP  \
# Albania  1950                                            NaN
#          1951                                            NaN
#          1952                                            NaN
#          1953                                            NaN
#          1954                                            NaN
# ...                                                      ...
# Zimbabwe 2018                                            NaN
#          2019                                            NaN
#          2020                                            NaN
#          2021                                            NaN
#          2022                                            NaN
#
#               Goods and Services Tax Revenue in Percent of GDP  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Financial Development Index Financial Institutions Index  \
# Albania  1950                         NaN                          NaN
#          1951                         NaN                          NaN
#          1952                         NaN                          NaN
#          1953                         NaN                          NaN
#          1954                         NaN                          NaN
# ...                                   ...                          ...
# Zimbabwe 2018                         NaN                          NaN
#          2019                         NaN                          NaN
#          2020                         NaN                          NaN
#          2021                         NaN                          NaN
#          2022                         NaN                          NaN
#
#               Financial Markets Index    Outcome
# Albania  1950                     NaN        NaN
#          1951                     NaN        NaN
#          1952                     NaN        NaN
#          1953                     NaN        NaN
#          1954                     NaN        NaN
# ...                               ...        ...
# Zimbabwe 2018                     NaN  46.825736
#          2019                     NaN  46.825736
#          2020                     NaN        NaN
#          2021                     NaN        NaN
#          2022                     NaN        NaN
#
# [12045 rows x 28 columns]

# %%
final_input_df = input_df.loc[final_countries]
final_input_df
# Out:
#                Treatment:Banking  Treatment:Currency  Treatment:Sovereign  \
# Albania  1950                  0                   0                    0
#          1951                  0                   0                    0
#          1952                  0                   0                    0
#          1953                  0                   0                    0
#          1954                  0                   0                    0
# ...                          ...                 ...                  ...
# Zimbabwe 2018                  0                   0                    0
#          2019                  0                   0                    0
#          2020                  0                   0                    0
#          2021                  0                   0                    0
#          2022                  0                   0                    0
#
#                Treatment:Sovereign_restructuring  \
# Albania  1950                                  0
#          1951                                  0
#          1952                                  0
#          1953                                  0
#          1954                                  0
# ...                                          ...
# Zimbabwe 2018                                  0
#          2019                                  0
#          2020                                  0
#          2021                                  0
#          2022                                  0
#
#               Gross domestic product, constant prices  \
# Albania  1950                                     NaN
#          1951                                     NaN
#          1952                                     NaN
#          1953                                     NaN
#          1954                                     NaN
# ...                                               ...
# Zimbabwe 2018                                   4.732
#          2019                                  -6.144
#          2020                                  -5.156
#          2021                                   7.159
#          2022                                   3.002
#
#               Output gap in percent of potential GDP  \
# Albania  1950                                    NaN
#          1951                                    NaN
#          1952                                    NaN
#          1953                                    NaN
#          1954                                    NaN
# ...                                              ...
# Zimbabwe 2018                                    NaN
#          2019                                    NaN
#          2020                                    NaN
#          2021                                    NaN
#          2022                                    NaN
#
#               Implied PPP conversion rate Total investment  \
# Albania  1950                         NaN              NaN
#          1951                         NaN              NaN
#          1952                         NaN              NaN
#          1953                         NaN              NaN
#          1954                         NaN              NaN
# ...                                   ...              ...
# Zimbabwe 2018                       1.032              NaN
#          2019                       5.482              NaN
#          2020                      36.237              NaN
#          2021                      79.482              NaN
#          2022                     356.582              NaN
#
#               Gross national savings Inflation, average consumer prices  ...  \
# Albania  1950                    NaN                                NaN  ...
#          1951                    NaN                                NaN  ...
#          1952                    NaN                                NaN  ...
#          1953                    NaN                                NaN  ...
#          1954                    NaN                                NaN  ...
# ...                              ...                                ...  ...
# Zimbabwe 2018                    NaN                             10.607  ...
#          2019                    NaN                            255.292  ...
#          2020                    NaN                             557.21  ...
#          2021                    NaN                             98.546  ...
#          2022                    NaN                            284.938  ...
#
#               Consumer Price Index, All items  \
# Albania  1950                             NaN
#          1951                             NaN
#          1952                             NaN
#          1953                             NaN
#          1954                             NaN
# ...                                       ...
# Zimbabwe 2018                          67.625
#          2019                         240.275
#          2020                1579.09166666667
#          2021                        3135.225
#          2022                             NaN
#
#               Financial, Interest Rates, Money Market, Percent per annum  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Cyclically adjusted balance (% of potential GDP)  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Official Reserve Assets, Foreign Currency Reserves (in Convertible Foreign Currencies), US Dollars  \
# Albania  1950                                                NaN
#          1951                                                NaN
#          1952                                                NaN
#          1953                                                NaN
#          1954                                                NaN
# ...                                                          ...
# Zimbabwe 2018                                                NaN
#          2019                                                NaN
#          2020                                                NaN
#          2021                                                NaN
#          2022                                                NaN
#
#               Corporate Income Tax Revenue in Percent of GDP  \
# Albania  1950                                            NaN
#          1951                                            NaN
#          1952                                            NaN
#          1953                                            NaN
#          1954                                            NaN
# ...                                                      ...
# Zimbabwe 2018                                            NaN
#          2019                                            NaN
#          2020                                            NaN
#          2021                                            NaN
#          2022                                            NaN
#
#               Goods and Services Tax Revenue in Percent of GDP  \
# Albania  1950                                              NaN
#          1951                                              NaN
#          1952                                              NaN
#          1953                                              NaN
#          1954                                              NaN
# ...                                                        ...
# Zimbabwe 2018                                              NaN
#          2019                                              NaN
#          2020                                              NaN
#          2021                                              NaN
#          2022                                              NaN
#
#               Financial Development Index Financial Institutions Index  \
# Albania  1950                         NaN                          NaN
#          1951                         NaN                          NaN
#          1952                         NaN                          NaN
#          1953                         NaN                          NaN
#          1954                         NaN                          NaN
# ...                                   ...                          ...
# Zimbabwe 2018                         NaN                          NaN
#          2019                         NaN                          NaN
#          2020                         NaN                          NaN
#          2021                         NaN                          NaN
#          2022                         NaN                          NaN
#
#               Financial Markets Index    Outcome
# Albania  1950                     NaN        NaN
#          1951                     NaN        NaN
#          1952                     NaN        NaN
#          1953                     NaN        NaN
#          1954                     NaN        NaN
# ...                               ...        ...
# Zimbabwe 2018                     NaN  46.825736
#          2019                     NaN  46.825736
#          2020                     NaN        NaN
#          2021                     NaN        NaN
#          2022                     NaN        NaN
#
# [8614 rows x 28 columns]

# %%
final_input_df.to_excel('../project/IMF_data/final_input_df.xlsx')
